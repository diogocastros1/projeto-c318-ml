# %% [markdown]
# # Previsão de valor do Biticoin
# ### Proposta do projeto
#
# Com a alta das criptomoedas, ter o auxilio de uma machine learning para ajudar nas decisões do dia a dia é uma ótima opção. Pensando nisso, nós criamos o modelo abaixo para efetuar a previsão do valor do bitcoin.
#
# ### Coleta de dados
#
# Para efetuar a previsão, o primeiro passo é alimentar o nosso sistema com dados, para isto iremos utilizar a api `CoinGecko` que nos fornece dados da abertura e fechamento do valor diário do Biticoin. Iremos tambem utilizar as seguintes bibliotecas do python
# - `requests` -> para efetuar as requisições na api;
# - `pandas` -> utilizado para organização e manipulação dos dados;
# - `matplotlib.pyplot` -> para efetuar a exibição de gráficos;
#
# #### Requisição para API
#
# A função `fetch_biticoin_data` é a responsável por fazer a requisição para API, para isto recebemos o numero de dias que desejamos consultar os dados, caso o numero de dias não seja passado, utilizamos 90 dias.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

def fetch_bitcoin_data(days=90):
    # Configurações da API da CoinGecko
    url = "https://api.coingecko.com/api/v3/coins/bitcoin/market_chart"
    params = {
        'vs_currency': 'usd',
        'days': str(days)   
    }

    # Fazer requisição para a API
    response = requests.get(url, params=params)
    data = response.json()

    # Verificar se os dados foram retornados corretamente
    if 'prices' in data:
        # Criar DataFrame com os preços
        df = pd.DataFrame(data['prices'], columns=['timestamp', 'close'])
        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
        df.set_index('timestamp', inplace=True)

        # Reordenar colunas
        df = df[['close']]
        return df
    else:
        print("Erro ao obter dados:", data)
        return None

# Obter dados do Bitcoin    
df = fetch_bitcoin_data()

# Agregar dados para obter o preço médio e final diário
df_daily = df.resample('D').agg({'close': ['mean', 'last']})
df_daily.columns = ['mean_price', 'final_price']  # Renomear colunas

# Exibir os primeiros dados agregados
print(df_daily.head())

# Plotar o gráfico
plt.figure(figsize=(12, 6))
plt.plot(df_daily.index, df_daily['mean_price'], label='Preço Médio Diário', linestyle='--')
plt.plot(df_daily.index, df_daily['final_price'], label='Preço de Fechamento Diário', linestyle='-')
plt.xlabel('Data')
plt.ylabel('Preço em USD')
plt.title('Preço Médio e de Fechamento Diário do Bitcoin')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#               mean_price   final_price
# timestamp
# 2024-08-31  58972.139215  58972.139215
# 2024-09-01  58229.481150  57383.549100
# 2024-09-02  58207.971020  59231.012844
# 2024-09-03  58649.355883  57786.552944
# 2024-09-04  57153.845225  58140.102892

# %% [markdown]
# ### Normalização de Dados e Preparação para LSTM
#
# Antes de alimentar nosso modelo LSTM (Long Short-Term Memory), precisamos normalizar os dados e organizá-los no formato adequado.
#
#
# #### Importação das Bibliotecas Necessárias
#
# Utilizamos a classe `MinMaxScaler` da biblioteca `sklearn` para normalizar os valores de fechamento do Bitcoin no intervalo entre 0 e 1.

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %% [markdown]
# #### Normalização dos Dados de Fechamento
# Utilizamos o `MinMaxScaler` para normalizar os preços de fechamento entre 0 e 1. A normalização é uma etapa crucial para melhorar o desempenho dos algoritmos de aprendizado de máquina, especialmente em redes neurais.

# %%
# Normalizar dados de fechamento
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df['close'].values.reshape(-1, 1))

# %% [markdown]
# - `MinMaxScaler` -> Transforma os dados para que fiquem dentro de um intervalo específico (neste caso, entre 0 e 1).
# - `reshape(-1, 1)` -> Ajusta os dados para a forma necessária pela função fit_transform.
#
# #### Criação do Conjunto de Dados para o LSTM
# Definimos uma função para criar conjuntos de dados de entrada (`X`) e saída (`Y`) para o modelo. Usaremos uma janela deslizante de 60 dias anteriores para prever o preço do próximo dia.

# %%
# Preparar dados para LSTM com intervalo diário
def create_dataset(dataset, look_back=60):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), 0])  # 60 dias anteriores
        Y.append(dataset[i + look_back, 0])      # Preço do dia seguinte
    return np.array(X), np.array(Y)

# %% [markdown]
# - Parâmetros:
#   - `dataset`: O conjunto de dados normalizado.
#   - `look_back`: Número de dias anteriores usados para prever o próximo valor (padrão é 60).
# - Retorna:
#   - `X`: Sequências de 60 dias de preços normalizados.
#   - `Y`: Preços normalizados correspondentes ao dia seguinte.

# %%
look_back = 60  # Usar 60 dias anteriores para prever o próximo
X, Y = create_dataset(scaled_data, look_back)

# %% [markdown]
# #### Reshape dos Dados para o Formato do LSTM
# O modelo LSTM espera os dados de entrada no formato de três dimensões: `[samples, time_steps, features]`. Ajustamos `X` para atender a esse formato.

# %%
X = np.reshape(X, (X.shape[0], X.shape[1], 1))  # Formato adequado para LSTM

# %% [markdown]
# ### Criação do Dataset para LSTM
# A função `create_dataset` é responsável por criar conjuntos de dados no formato necessário para o modelo LSTM. Usamos um intervalo de 60 dias anteriores (`look_back`) para prever o preço do dia seguinte.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Construir o modelo LSTM
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compilar o modelo
model.compile(optimizer='adam', loss='mean_squared_error')

# Treinar o modelo
model.fit(X, Y, epochs=50, batch_size=16)

# Dividir os dados em treinamento e teste
train_size = int(len(scaled_data) * 0.8)
train, test = scaled_data[0:train_size], scaled_data[train_size:]

# Preparar dados para treino e teste
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# Ajustar dimensões para LSTM
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Treinar o modelo
model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_data=(X_test, Y_test))

# Fazer previsões e reverter a normalização
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
Y_test = scaler.inverse_transform([Y_test])
# Out:
# Epoch 1/50
# c:\Users\diogoantonio\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0227
# Epoch 2/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0024
# Epoch 3/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0025
# Epoch 4/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0019
# Epoch 5/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0020
# Epoch 6/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0020
# Epoch 7/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0020
# Epoch 8/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0015
# Epoch 9/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0014
# Epoch 10/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0015
# Epoch 11/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0015
# Epoch 12/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0014
# Epoch 13/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0013
# Epoch 14/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0011
# Epoch 15/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0012
# Epoch 16/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0012
# Epoch 17/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0012
# Epoch 18/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0012
# Epoch 19/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0012
# Epoch 20/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0010
# Epoch 21/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.5622e-04
# Epoch 22/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 9.8100e-04
# Epoch 23/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.9811e-04
# Epoch 24/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.7159e-04
# Epoch 25/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.7632e-04
# Epoch 26/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.1716e-04
# Epoch 27/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.8101e-04
# Epoch 28/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.5019e-04
# Epoch 29/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 9.6305e-04
# Epoch 30/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.2815e-04
# Epoch 31/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.0426e-04
# Epoch 32/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.5783e-04
# Epoch 33/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.0391e-04
# Epoch 34/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.9048e-04
# Epoch 35/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.2892e-04
# Epoch 36/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.2957e-04
# Epoch 37/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.7873e-04
# Epoch 38/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.5621e-04
# Epoch 39/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.3416e-04
# Epoch 40/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.2892e-04
# Epoch 41/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.9923e-04
# Epoch 42/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.5681e-04
# Epoch 43/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.7707e-04
# Epoch 44/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.3434e-04
# Epoch 45/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.7825e-04
# Epoch 46/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.5852e-04
# Epoch 47/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.8902e-04
# Epoch 48/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.0374e-04
# Epoch 49/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.3460e-04
# Epoch 50/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.3013e-04
# Epoch 1/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.3958e-04 - val_loss: 5.1025e-04
# Epoch 2/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.9056e-04 - val_loss: 4.4685e-04
# Epoch 3/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.5882e-04 - val_loss: 4.7092e-04
# Epoch 4/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6268e-04 - val_loss: 2.8458e-04
# Epoch 5/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6404e-04 - val_loss: 2.7084e-04
# Epoch 6/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6623e-04 - val_loss: 3.2141e-04
# Epoch 7/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2907e-04 - val_loss: 2.4610e-04
# Epoch 8/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5229e-04 - val_loss: 3.8489e-04
# Epoch 9/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.5006e-04 - val_loss: 3.1120e-04
# Epoch 10/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4407e-04 - val_loss: 2.8752e-04
# Epoch 11/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3544e-04 - val_loss: 2.2635e-04
# Epoch 12/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3278e-04 - val_loss: 3.7059e-04
# Epoch 13/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4652e-04 - val_loss: 2.2595e-04
# Epoch 14/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.6778e-04 - val_loss: 3.6572e-04
# Epoch 15/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3102e-04 - val_loss: 2.2220e-04
# Epoch 16/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.2126e-04 - val_loss: 2.2117e-04
# Epoch 17/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0180e-04 - val_loss: 2.4004e-04
# Epoch 18/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9492e-04 - val_loss: 2.2691e-04
# Epoch 19/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0471e-04 - val_loss: 2.2713e-04
# Epoch 20/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3711e-04 - val_loss: 4.8953e-04
# Epoch 21/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0082e-04 - val_loss: 2.1505e-04
# Epoch 22/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9908e-04 - val_loss: 3.0699e-04
# Epoch 23/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9054e-04 - val_loss: 2.1004e-04
# Epoch 24/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7503e-04 - val_loss: 2.1198e-04
# Epoch 25/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0175e-04 - val_loss: 2.0862e-04
# Epoch 26/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9684e-04 - val_loss: 7.0729e-04
# Epoch 27/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3461e-04 - val_loss: 5.1632e-04
# Epoch 28/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1059e-04 - val_loss: 3.8264e-04
# Epoch 29/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8437e-04 - val_loss: 2.0768e-04
# Epoch 30/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0832e-04 - val_loss: 2.0638e-04
# Epoch 31/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.2250e-04 - val_loss: 2.6514e-04
# Epoch 32/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9945e-04 - val_loss: 5.2537e-04
# Epoch 33/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9192e-04 - val_loss: 2.5682e-04
# Epoch 34/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.1174e-04 - val_loss: 8.3425e-04
# Epoch 35/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0952e-04 - val_loss: 3.2491e-04
# Epoch 36/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.2878e-04 - val_loss: 2.5779e-04
# Epoch 37/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9965e-04 - val_loss: 2.0043e-04
# Epoch 38/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1266e-04 - val_loss: 8.2886e-04
# Epoch 39/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1819e-04 - val_loss: 4.8961e-04
# Epoch 40/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0232e-04 - val_loss: 2.5841e-04
# Epoch 41/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9988e-04 - val_loss: 3.7012e-04
# Epoch 42/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9217e-04 - val_loss: 4.4416e-04
# Epoch 43/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1845e-04 - val_loss: 4.4217e-04
# Epoch 44/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0229e-04 - val_loss: 4.2407e-04
# Epoch 45/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8578e-04 - val_loss: 6.2176e-04
# Epoch 46/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0159e-04 - val_loss: 3.1012e-04
# Epoch 47/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8181e-04 - val_loss: 4.3486e-04
# Epoch 48/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7452e-04 - val_loss: 2.1888e-04
# Epoch 49/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7268e-04 - val_loss: 4.8024e-04
# Epoch 50/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0211e-04 - val_loss: 1.8852e-04
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step

# %%
# Calcular RMSE e MAE
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error

rmse = math.sqrt(mean_squared_error(Y_test[0], predictions[:, 0]))
mae = mean_absolute_error(Y_test[0], predictions[:, 0])
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')

# Gráfico de comparação

plt.figure(figsize=(12, 6))
plt.plot(Y_test[0], label='Valor Real')
plt.plot(predictions[:, 0], label='Previsão')
plt.xlabel('Tempo')
plt.ylabel('Preço')
plt.title('Previsão vs Valor Real')
plt.legend()
plt.show()
# Out:
# RMSE: 904.9445585295922
# MAE: 790.1834921616953

# %%
# Prever o próximo valor do Bitcoin
def predict_next_value(model, data, scaler, look_back=60):
    # Selecionar os últimos `look_back` dias para a previsão
    last_data = data[-look_back:]
    last_data = last_data.reshape(1, look_back, data.shape[1])  # Formatar para o modelo LSTM
    
    # Fazer a previsão
    prediction = model.predict(last_data)
    
    # Desnormalizar a previsão
    prediction = scaler.inverse_transform(np.concatenate([prediction, np.zeros((1, data.shape[1] - 1))], axis=1))[0, 0]
    return prediction

# Previsão do próximo valor
next_value = predict_next_value(model, scaled_data, scaler)
print(f"O valor previsto do Bitcoin para o próximo momento é: ${next_value:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# O valor previsto do Bitcoin para o próximo momento é: $97400.57
